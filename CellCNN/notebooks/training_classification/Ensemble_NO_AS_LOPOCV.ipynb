# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install flowio
# Out:
# Collecting flowio
#   Downloading flowio-1.4.0.tar.gz (19 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.12/dist-packages (from flowio) (2.0.2)
# Building wheels for collected packages: flowio
#   Building wheel for flowio (pyproject.toml) ... done
#   Created wheel for flowio: filename=flowio-1.4.0-py3-none-any.whl size=21897 sha256=65276480206ed17891c8e2b5e55eef02469f37e928ba65cc4261271f29cb840a
#   Stored in directory: /root/.cache/pip/wheels/85/ac/b0/1e3bf1774da784e601a026a80622d0a25979d52ef416c0e027
# Successfully built flowio
# Installing collected packages: flowio
# Successfully installed flowio-1.4.0

# %%
import shutil
import pandas as pd
import random
import copy
import numpy as np # Import numpy for checking finite values
import matplotlib.pyplot as plt # Import matplotlib for potential debugging
import os
import math

PYTHONHASHSEED = '42'
TF_DETERMINISTIC_OPS = '1'
TF_CUDNN_DETERMINISTIC = '1'
os.environ['PYTHONHASHSEED'] = '42'
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'  # For CuDNN ops


import glob
import json
import tensorflow as tf
import sys
import pickle
import time
import csv
import traceback
import gc

from sklearn import metrics
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score

# %%
fixed_path = '/content/drive/MyDrive/0.Master_Thesis/'

if fixed_path not in sys.path:
    sys.path.append(fixed_path)

cellcnn_path = f'{fixed_path}CellCNN/'
if cellcnn_path not in sys.path:
    sys.path.append(cellcnn_path)

model_path = f'{cellcnn_path}Old_CellCNN/'
if model_path not in sys.path:
    sys.path.append(model_path)

save_path = f'{cellcnn_path}results/'
if save_path not in sys.path:
    sys.path.append(save_path)

modules_dir = f'{cellcnn_path}modules/'
if modules_dir not in sys.path:
    sys.path.append(modules_dir)

# %%
decache_files = ['timepoints_elaboration', 'model_grid', 'run_models', 'new_datasets_generation',
                'training', 'utils', 'cv_folds', 'classification']


# Remove from cache
from utils import remove_from_cache
remove_from_cache(decache_files)

from model_grid import CellCnn

from timepoints_elaboration import load_data, donation_extraction
from run_models import  trials_train_CellCNN_old, trials_test_CellCNN_old
from new_datasets_generation import splitting_and_dataset_elaboration

from training import run_training, val_res_pred, train_val_finalizing, test_res_pred, find_theta_best
from utils import flatten, remove_labels, retrieve_labels, show_blast_distribution_perc
from utils import prepare_results_to_save, subset_sampling, generate_seeds
from utils import nsub_ncells_comb, save_models, load_models
from cv_folds import generate_LOPOCV_dicts, generate_LOPOCV_folds, extract_fold_features
from classification import find_robust_threshold
# Out:
# timepoints_elaboration not found in cache
# model_grid not found in cache
# run_models not found in cache
# new_datasets_generation not found in cache
# training not found in cache
# utils removed from cache
# cv_folds not found in cache
# classification not found in cache

# %% [markdown]
# # Single Cell Run

# %%
tuning_exp = 'Trial_5_fix_code_NO_AS_bayesian_tuning'


config_save_dir = f'{cellcnn_path}/experiments/experiment_{tuning_exp}/'
os.makedirs(config_save_dir, exist_ok=True)

with open(os.path.join(config_save_dir, 'config.pkl'), 'rb') as f:
            config = pickle.load(f)

starting_seed = config['starting_seed']
n_sub = config['n_sub ']
n_cells = config['n_cells']
blast_perc = config['blast_perc']
nfilter = config['nfilter']
maxpool_p = config['maxpool_p']
learning_r = config['learning_r']
labels = config['labels']  # if False internal data augmentation do not takes in account true subset condition

hyper = (nfilter, maxpool_p, learning_r)

print(starting_seed)
print(n_sub)
print(n_cells)
print(blast_perc)
print(nfilter)
print(maxpool_p)
print(learning_r)
print(labels)
# Out:
# 1000
# 3
# 100000
# [0.0001, 0.001, 0.01]
# [5, 7, 9]
# [0.01, 1, 10, 100]
# [0.001, 0.005]
# False

# %%
# %%time

# Trova tutti i file con estensione specifica in una cartella
data_folder = f'{fixed_path}B-ALL_Datasets'
extension = '*.csv'  # cambia con l'estensione che ti serve

multiple_donations, ALL_DATASETS = load_data(data_path = data_folder, ext = extension)#, remove_control = True)
# Out:
# Elaborating file 0: /content/drive/MyDrive/0.Master_Thesis/B-ALL_Datasets/B-ALL_expression_matrix_B-ALL_GHE1_D15_2.csv
# Elaborating file 1: /content/drive/MyDrive/0.Master_Thesis/B-ALL_Datasets/B-ALL_expression_matrix_B-ALL_GHE1_D78.csv
# Elaborating file 2: /content/drive/MyDrive/0.Master_Thesis/B-ALL_Datasets/B-ALL_expression_matrix_B-ALL_GHE11_D15_1.csv
# Elaborating file 3: /content/drive/MyDrive/0.Master_Thesis/B-ALL_Datasets/B-ALL_expression_matrix_B-ALL_GHE11_D29_1.csv
# Elaborating file 4: /content/drive/MyDrive/0.Master_Thesis/B-ALL_Datasets/B-ALL_expression_matrix_B-ALL_GHE11_D71_1.csv
# Elaborating file 5: /content/drive/MyDrive/0.Master_Thesis/B-ALL_Datasets/B-ALL_expression_matrix_B-ALL_GHE12_D15_2.csv
# Elaborating file 6: /content/drive/MyDrive/0.Master_Thesis/B-ALL_Datasets/B-ALL_expression_matrix_B-ALL_GHE12_D29_1.csv
# Elaborating file 7: /content/drive/MyDrive/0.Master_Thesis/B-ALL_Datasets/B-ALL_expression_matrix_B-ALL_GHE2_D15_2.csv
# Elaborating file 8: /content/drive/MyDrive/0.Master_Thesis/B-ALL_Datasets/B-ALL_expression_matrix_B-ALL_GHE2_D29.csv
# Elaborating file 9: /content/drive/MyDrive/0.Master_Thesis/B-ALL_Datasets/B-ALL_expression_matrix_B-ALL_GHE3_D15_2.csv
# Elaborating file 10: /content/drive/MyDrive/0.Master_Thesis/B-ALL_Datasets/B-ALL_expression_matrix_B-ALL_GHE3_D71.csv
# Elaborating file 11: /content/drive/MyDrive/0.Master_Thesis/B-ALL_Datasets/B-ALL_expression_matrix_B-ALL_GHE4_D15_2.csv
# Elaborating file 12: /content/drive/MyDrive/0.Master_Thesis/B-ALL_Datasets/B-ALL_expression_matrix_B-ALL_GHE4_D29.csv
# Elaborating file 13: /content/drive/MyDrive/0.Master_Thesis/B-ALL_Datasets/B-ALL_expression_matrix_B-ALL_GHE4_D71.csv
# Elaborating file 14: /content/drive/MyDrive/0.Master_Thesis/B-ALL_Datasets/B-ALL_expression_matrix_B-ALL_GHE6_D15_2.csv
# Elaborating file 15: /content/drive/MyDrive/0.Master_Thesis/B-ALL_Datasets/B-ALL_expression_matrix_B-ALL_GHE6_D29.csv
# Elaborating file 16: /content/drive/MyDrive/0.Master_Thesis/B-ALL_Datasets/B-ALL_expression_matrix_B-ALL_GHE7_D15_2.csv
# Elaborating file 17: /content/drive/MyDrive/0.Master_Thesis/B-ALL_Datasets/B-ALL_expression_matrix_B-ALL_GHE7_D29_2.csv
# Elaborating file 18: /content/drive/MyDrive/0.Master_Thesis/B-ALL_Datasets/B-ALL_expression_matrix_B-ALL_GHE7_D71_2.csv
# Elaborating file 19: /content/drive/MyDrive/0.Master_Thesis/B-ALL_Datasets/B-ALL_expression_matrix_B-ALL_GHE8_D15_2.csv
# Elaborating file 20: /content/drive/MyDrive/0.Master_Thesis/B-ALL_Datasets/B-ALL_expression_matrix_B-ALL_GHE8_D71.csv
# Elaborating file 21: /content/drive/MyDrive/0.Master_Thesis/B-ALL_Datasets/B-ALL_expression_matrix_B-ALL_GHE9_D15_2.csv
# Elaborating file 22: /content/drive/MyDrive/0.Master_Thesis/B-ALL_Datasets/B-ALL_expression_matrix_B-ALL_GHE9_D29_2.csv
# CPU times: user 1min 3s, sys: 10.8 s, total: 1min 14s
# Wall time: 2min 18s

# %%
tot_perc_list = show_blast_distribution_perc(ALL_DATASETS, multiple_donations, return_perc = True)
print(tot_perc_list)
# Out:
# [np.float64(0.09), np.float64(0.0), np.float64(39.56), np.float64(15.06), np.float64(0.03), np.float64(0.0), np.float64(1.93), np.float64(0.04), np.float64(0.0), np.float64(1.44), np.float64(0.01), np.float64(0.31), np.float64(0.21), np.float64(0.0), np.float64(0.5), np.float64(0.02), np.float64(27.79), np.float64(0.28), np.float64(0.16), np.float64(0.01), np.float64(0.0), np.float64(0.15), np.float64(0.0)]

# %%
full_LOPOCV_dicts = generate_LOPOCV_dicts(multiple_donations, ALL_DATASETS)
LOPOCV_patients_folds = generate_LOPOCV_folds(full_LOPOCV_dicts, ALL_DATASETS, starting_seed)
# Out:
# dict_keys(['2', '3', '4', '6', '7', '8', '9', '11', '12']) dict_keys(['1']) [np.float64(0.08762), np.float64(0.0)]
# dict_keys(['1', '3', '4', '6', '7', '8', '9', '11', '12']) dict_keys(['2']) [np.float64(39.55814), np.float64(15.0633)]
# dict_keys(['1', '2', '4', '6', '7', '8', '9', '11', '12']) dict_keys(['3']) [np.float64(0.03462), np.float64(0.0)]
# dict_keys(['1', '2', '3', '6', '7', '8', '9', '11', '12']) dict_keys(['4']) [np.float64(1.92897), np.float64(0.04035), np.float64(0.0)]
# dict_keys(['1', '2', '3', '4', '7', '8', '9', '11', '12']) dict_keys(['6']) [np.float64(1.43503), np.float64(0.00775)]
# dict_keys(['1', '2', '3', '4', '6', '8', '9', '11', '12']) dict_keys(['7']) [np.float64(0.31479), np.float64(0.20732), np.float64(0.0)]
# dict_keys(['1', '2', '3', '4', '6', '7', '9', '11', '12']) dict_keys(['8']) [np.float64(0.49896), np.float64(0.01692)]
# dict_keys(['1', '2', '3', '4', '6', '7', '8', '11', '12']) dict_keys(['9']) [np.float64(27.7918), np.float64(0.2798)]
# dict_keys(['1', '2', '3', '4', '6', '7', '8', '9', '12']) dict_keys(['11']) [np.float64(0.15981), np.float64(0.01211), np.float64(0.0)]
# dict_keys(['1', '2', '3', '4', '6', '7', '8', '9', '11']) dict_keys(['12']) [np.float64(0.1483), np.float64(0.00208)]
# Remaining Patients: healthy = [], unhealthy = ['2', '6', '8', '9', '12'], mixed = ['3', '4', '7', '11']
# All Patients in Train + Validation set: ['2', '3', '6', '4', '8', '7', '9', '11', '12']
# Folds: [['6'], ['9', '7'], ['3', '8'], ['12', '2'], ['11', '4']]
# Combination 1: (['6', '9', '7', '3', '8', '12', '2'], ['11', '4'])
# Combination 2: (['9', '7', '3', '8', '12', '2', '11', '4'], ['6'])
# Combination 3: (['6', '3', '8', '12', '2', '11', '4'], ['9', '7'])
# Combination 4: (['6', '9', '7', '12', '2', '11', '4'], ['3', '8'])
# Combination 5: (['6', '9', '7', '3', '8', '11', '4'], ['12', '2'])
# Remaining Patients: healthy = [], unhealthy = ['6', '8', '9', '12'], mixed = ['1', '3', '4', '7', '11']
# All Patients in Train + Validation set: ['6', '1', '8', '3', '9', '4', '12', '7', '11']
# Folds: [['1'], ['7', '11'], ['4', '3'], ['12', '8'], ['6', '9']]
# Combination 1: (['1', '7', '11', '4', '3', '12', '8'], ['6', '9'])
# Combination 2: (['7', '11', '4', '3', '12', '8', '6', '9'], ['1'])
# Combination 3: (['1', '4', '3', '12', '8', '6', '9'], ['7', '11'])
# Combination 4: (['1', '7', '11', '12', '8', '6', '9'], ['4', '3'])
# Combination 5: (['1', '7', '11', '4', '3', '6', '9'], ['12', '8'])
# Remaining Patients: healthy = [], unhealthy = ['2', '6', '8', '9', '12'], mixed = ['1', '4', '7', '11']
# All Patients in Train + Validation set: ['2', '1', '6', '4', '8', '7', '9', '11', '12']
# Folds: [['6'], ['4', '12'], ['2', '8'], ['9', '7'], ['1', '11']]
# Combination 1: (['6', '4', '12', '2', '8', '9', '7'], ['1', '11'])
# Combination 2: (['4', '12', '2', '8', '9', '7', '1', '11'], ['6'])
# Combination 3: (['6', '2', '8', '9', '7', '1', '11'], ['4', '12'])
# Combination 4: (['6', '4', '12', '9', '7', '1', '11'], ['2', '8'])
# Combination 5: (['6', '4', '12', '2', '8', '1', '11'], ['9', '7'])
# Remaining Patients: healthy = [], unhealthy = ['2', '6', '8', '9', '12'], mixed = ['1', '3', '7', '11']
# All Patients in Train + Validation set: ['2', '1', '6', '3', '8', '7', '9', '11', '12']
# Folds: [['3'], ['6', '7'], ['8', '2'], ['9', '12'], ['11', '1']]
# Combination 1: (['3', '6', '7', '8', '2', '9', '12'], ['11', '1'])
# Combination 2: (['6', '7', '8', '2', '9', '12', '11', '1'], ['3'])
# Combination 3: (['3', '8', '2', '9', '12', '11', '1'], ['6', '7'])
# Combination 4: (['3', '6', '7', '9', '12', '11', '1'], ['8', '2'])
# Combination 5: (['3', '6', '7', '8', '2', '11', '1'], ['9', '12'])
# Remaining Patients: healthy = [], unhealthy = ['2', '8', '9', '12'], mixed = ['1', '3', '4', '7', '11']
# All Patients in Train + Validation set: ['2', '1', '8', '3', '9', '4', '12', '7', '11']
# Folds: [['3'], ['11', '8'], ['1', '12'], ['7', '4'], ['9', '2']]
# Combination 1: (['3', '11', '8', '1', '12', '7', '4'], ['9', '2'])
# Combination 2: (['11', '8', '1', '12', '7', '4', '9', '2'], ['3'])
# Combination 3: (['3', '1', '12', '7', '4', '9', '2'], ['11', '8'])
# Combination 4: (['3', '11', '8', '7', '4', '9', '2'], ['1', '12'])
# Combination 5: (['3', '11', '8', '1', '12', '9', '2'], ['7', '4'])
# Remaining Patients: healthy = [], unhealthy = ['2', '6', '8', '9', '12'], mixed = ['1', '3', '4', '11']
# All Patients in Train + Validation set: ['2', '1', '6', '3', '8', '4', '9', '11', '12']
# Folds: [['4'], ['3', '9'], ['12', '2'], ['11', '1'], ['6', '8']]
# Combination 1: (['4', '3', '9', '12', '2', '11', '1'], ['6', '8'])
# Combination 2: (['3', '9', '12', '2', '11', '1', '6', '8'], ['4'])
# Combination 3: (['4', '12', '2', '11', '1', '6', '8'], ['3', '9'])
# Combination 4: (['4', '3', '9', '11', '1', '6', '8'], ['12', '2'])
# Combination 5: (['4', '3', '9', '12', '2', '6', '8'], ['11', '1'])
# Remaining Patients: healthy = [], unhealthy = ['2', '6', '9', '12'], mixed = ['1', '3', '4', '7', '11']
# All Patients in Train + Validation set: ['2', '1', '6', '3', '9', '4', '12', '7', '11']
# Folds: [['1'], ['11', '6'], ['3', '2'], ['7', '4'], ['12', '9']]
# Combination 1: (['1', '11', '6', '3', '2', '7', '4'], ['12', '9'])
# Combination 2: (['11', '6', '3', '2', '7', '4', '12', '9'], ['1'])
# Combination 3: (['1', '3', '2', '7', '4', '12', '9'], ['11', '6'])
# Combination 4: (['1', '11', '6', '7', '4', '12', '9'], ['3', '2'])
# Combination 5: (['1', '11', '6', '3', '2', '12', '9'], ['7', '4'])
# Remaining Patients: healthy = [], unhealthy = ['2', '6', '8', '12'], mixed = ['1', '3', '4', '7', '11']
# All Patients in Train + Validation set: ['2', '1', '6', '3', '8', '4', '12', '7', '11']
# Folds: [['12'], ['8', '2'], ['7', '6'], ['3', '11'], ['1', '4']]
# Combination 1: (['12', '8', '2', '7', '6', '3', '11'], ['1', '4'])
# Combination 2: (['8', '2', '7', '6', '3', '11', '1', '4'], ['12'])
# Combination 3: (['12', '7', '6', '3', '11', '1', '4'], ['8', '2'])
# Combination 4: (['12', '8', '2', '3', '11', '1', '4'], ['7', '6'])
# Combination 5: (['12', '8', '2', '7', '6', '1', '4'], ['3', '11'])
# Remaining Patients: healthy = [], unhealthy = ['2', '6', '8', '9', '12'], mixed = ['1', '3', '4', '7']
# All Patients in Train + Validation set: ['2', '1', '6', '3', '8', '4', '9', '7', '12']
# Folds: [['12'], ['1', '3'], ['2', '9'], ['8', '7'], ['6', '4']]
# Combination 1: (['12', '1', '3', '2', '9', '8', '7'], ['6', '4'])
# Combination 2: (['1', '3', '2', '9', '8', '7', '6', '4'], ['12'])
# Combination 3: (['12', '2', '9', '8', '7', '6', '4'], ['1', '3'])
# Combination 4: (['12', '1', '3', '8', '7', '6', '4'], ['2', '9'])
# Combination 5: (['12', '1', '3', '2', '9', '6', '4'], ['8', '7'])
# Remaining Patients: healthy = [], unhealthy = ['2', '6', '8', '9'], mixed = ['1', '3', '4', '7', '11']
# All Patients in Train + Validation set: ['2', '1', '6', '3', '8', '4', '9', '7', '11']
# Folds: [['1'], ['7', '4'], ['2', '11'], ['8', '6'], ['3', '9']]
# Combination 1: (['1', '7', '4', '2', '11', '8', '6'], ['3', '9'])
# Combination 2: (['7', '4', '2', '11', '8', '6', '3', '9'], ['1'])
# Combination 3: (['1', '2', '11', '8', '6', '3', '9'], ['7', '4'])
# Combination 4: (['1', '7', '4', '8', '6', '3', '9'], ['2', '11'])
# Combination 5: (['1', '7', '4', '2', '11', '3', '9'], ['8', '6'])

# %%
# %%time

start_lopocv_fold = 0
end_lopocv_fold = 0

exp = 'Trial_5_fix_code_NO_AS_Ensemble'

save_memory = False # set True to save RAM memory
grid = True

weights_outdir = f'{config_save_dir}/weights'
os.makedirs(weights_outdir, exist_ok=True)
full_process_time_list = []

for LOPOCV_fold_idx, (train_kfolds, test_pat) in enumerate(LOPOCV_patients_folds): # for each LOPO fold
  if LOPOCV_fold_idx >= start_lopocv_fold:

    LOPOCV_start = time.time()

    # === Import Base seed === #
    seed_load_dir = f'{cellcnn_path}/experiments/experiment_{tuning_exp}/outer_fold_{LOPOCV_fold_idx}/'

    with open(os.path.join(seed_load_dir, 'tuning_seed_info.pkl'), 'rb') as f:
                            seed_info = pickle.load(f)

    print('check seeds:', seed_info)
    training_split_seed = seed_info['final_tuning_base_seed']
    fold_base_seed = seed_info['fold_base_seed']

    # === Import Tuned theta* === #

    tuning_load_dir = f'{cellcnn_path}/experiments/experiment_{tuning_exp}/outer_fold_{LOPOCV_fold_idx}/tuning/results'

    with open(os.path.join(tuning_load_dir, 'best_ncells.pkl'), 'rb') as f:
                        best_ncells = pickle.load(f)

    with open(os.path.join(tuning_load_dir, 'best_nsub.pkl'), 'rb') as f:
                        best_nsub = pickle.load(f)

    print(f'Theta*: {best_ncells, best_nsub}')


    base_seed = fold_base_seed

    if save_memory:
        if LOPOCV_fold_idx != start_lopocv_fold:
            multiple_donations, ALL_DATASETS = load_data(data_path = data_folder, ext = extension)

    # retrieve train and val patients per fold
    fold_features = extract_fold_features(train_kfolds, multiple_donations, tot_perc_list) #Fold feature dictionary creation

    # fix seed for comparisons
    base_seed = training_split_seed
    for i in range(1):

            # prepare storing variables
            best_thresholds = []       # save thresholds
            roc_metrics = []
            val_predicted_for_roc = [] # store predictions from tuning for threshold tuning

            print(f'Model {i+1}. Testing params -> ncells: {best_ncells}, nsubs: {best_nsub}')
            print(f'5 Fold CV started')

            val_predicted_for_roc_folds = []
            f1_across_folds = []

            for fold_idx, (train_features, val_features) in fold_features.items():
                print(f'\nCV Fold {fold_idx} starts (LOPOCV iteration: {LOPOCV_fold_idx})\n')
                fold_start = time.time()

                print('Loading data...')
                train_donors_idx, val_donors_idx = train_features[0], val_features[0] # retrieve patients form fold features dictionary

                if save_memory:
                    multiple_donations, ALL_DATASETS = load_data(data_path = data_folder, ext = extension)

                # extraxt samples using pre-slitted indexes
                train_datasets_extracted = donation_extraction(train_donors_idx, multiple_donations, ALL_DATASETS)
                val_datasets_extracted = donation_extraction(val_donors_idx, multiple_donations, ALL_DATASETS)
                test_datasets_extracted = donation_extraction(test_pat, multiple_donations, ALL_DATASETS)

                if save_memory:
                  del ALL_DATASETS

                # retireve Train and Validation labels
                original_train_datasets, original_train_y = retrieve_labels(train_datasets_extracted, remove = True, flat = True)
                original_val_datasets, original_val_y = retrieve_labels(val_datasets_extracted, remove = True, flat = True)

                # remove labels (random search without labels is required)
                train, val = train_val_finalizing(original_train_datasets, original_val_datasets, grid, labels) # prepare dataset for the training

                tuning_predictions = []
                tuning_results = []

                print('Data Loaded...')

                trials = 1 #number of weights initializations

                # === Generate seed lists in advance === #

                train_CV_seed = base_seed + i*1000 + fold_idx*10 + 1
                seed_list = generate_seeds(len(LOPOCV_patients_folds)*2, seed = train_CV_seed)

                pred_CV_seed = base_seed + i*1000 + fold_idx*10 + len(fold_features)*10
                tuning_prediction_seed_list = generate_seeds(trials, seed = pred_CV_seed)

                base_seed += 200
                final_orig_pred_seed = base_seed
                original_prediction_seed_list = generate_seeds(trials, seed = final_orig_pred_seed)

                base_seed += 1000

                final_rob_pred_seed = base_seed
                robust_prediction_seed_list = generate_seeds(3, seed = final_rob_pred_seed)

                try:

                        # === Train Models === #

                        models_lists = run_training(CellCnn,
                                            train, original_train_y,
                                            new_val_datasets = val, new_val_y = original_val_y,
                                            seed_list =  seed_list, hyper = hyper, grid = grid, labels = labels,
                                            trials = trials,
                                            cells_per_sub = best_ncells, ## Tuned ncells ##
                                            best_nsub = best_nsub,        ## Tuned nsub   ##
                                            max_epochs = 1,              ### 100,
                                            nrun = None,                  #grid search, so doesn't matter wht number
                                            generate = False,
                                            outdir = weights_outdir)


                        # === Save Models === #
                        for trial_i, model in enumerate(models_lists):
                            save_dir = f'{cellcnn_path}/experiments/experiment_{exp}/outer_fold_{LOPOCV_fold_idx}/ensemble/training/inner_fold_{fold_idx}/models/seed_{trial_i}'
                            os.makedirs(save_dir, exist_ok=True)
                            save_models(model, save_dir)

                        # === Prediction Approach: CellCNN with tau = 0.5 === #

                        if save_memory:
                            print('Load data for Test set')
                            multiple_donations, ALL_DATASETS = load_data(data_path = data_folder, ext = extension)

                        test_datasets_extracted = donation_extraction(test_pat, multiple_donations, ALL_DATASETS)

                        original_test_datasets, original_test_y = retrieve_labels(test_datasets_extracted, remove = True, flat = True)
                        print(f'Ground thruth labels: {original_test_y}')

                        # Test set prediction
                        original_predictions_list, original_results_list = trials_test_CellCNN_old(models_lists, original_test_datasets, original_prediction_seed_list)

                        print('Save CellCNN Prediction results')
                        save_original_dir = f'{cellcnn_path}/experiments/experiment_{exp}/outer_fold_{LOPOCV_fold_idx}/ensemble/results/inner_fold_{fold_idx}/predictions/direct'
                        os.makedirs(save_original_dir, exist_ok=True)

                        with open(os.path.join(save_original_dir, 'original_predictions_list.pkl'), 'wb') as f:
                                        pickle.dump(original_predictions_list, f)
                        with open(os.path.join(save_original_dir, 'original_results_list.pkl'), 'wb') as f:
                                        pickle.dump(original_results_list, f)
                        with open(os.path.join(save_original_dir, 'original_test_y.pkl'), 'wb') as f:
                                        pickle.dump(original_test_y, f)


                        # === Prediction Approach: Resamplimg === #

                        print('Start Resampling prediction using ROC threshold')

                        test_resample_n = 100000 #same dimension of AS
                        k = 2 ### 100

                        per_donor_original_test_datasets, per_donor_original_test_y = retrieve_labels(test_datasets_extracted, remove = False)
                        print(f'Ground thruth labels per patient: {per_donor_original_test_y}')

                        (_,      # test_total_labels,                                  # Predicted resampled subsets labels
                            test_total_pred_lists,                                        # Mean predictions of resampled subsets across trials (per patient)
                            test_total_trial_pred_lists,                                  # Lists of trial predictions of resampled subsets (per patient)
                            per_donor_resampled_test_y                                    # True labels of resampled subsets (per patient)
                                                      ) = test_res_pred(
                                                          models_lists,
                                                          per_donor_original_test_datasets,
                                                          test_resample_n,
                                                          k,
                                                          0.5,                           # doesn't msatter. We are interested only to the predictions
                                                          trials,
                                                          seed = robust_prediction_seed_list[1])



                        save_robust_dir = f'{cellcnn_path}/experiments/experiment_{exp}/outer_fold_{LOPOCV_fold_idx}/ensemble/results/inner_fold_{fold_idx}/predictions/robust/'
                        os.makedirs(save_robust_dir, exist_ok=True)

                        with open(os.path.join(save_robust_dir, 'test_total_trial_pred_lists.pkl'), 'wb') as f:
                                        pickle.dump(test_total_trial_pred_lists, f)
                        with open(os.path.join(save_robust_dir, 'per_donor_resampled_test_y.pkl'), 'wb') as f:
                                        pickle.dump(per_donor_resampled_test_y, f)
                        with open(os.path.join(save_robust_dir, 'per_donor_original_test_y.pkl'), 'wb') as f:
                                        pickle.dump(per_donor_original_test_y, f)


                except Exception as e:
                        print(f"Training error: {e}")
                        traceback.print_exc()

                fold_end = time.time()
                print('')
                print(f'End CV Fold {fold_idx}. Time Elapsed: {fold_start - fold_end}')
                print(f'Time elapsed from start LOPOCV iteration: {LOPOCV_start - fold_end}')
                print('')

            if save_memory:
                multiple_donations, ALL_DATASETS = load_data(data_path = data_folder, ext = extension)

            try:

                        # === Threshold tuning: \tau^*_{ROC} and \tau^*_{RES} === #

                        print('Start post-training Threshold tuning')

                        ensemble_mean_probs_per_patient = [] # mean across weights initializations per patient
                        ensamble_val_y = []                  #
                        ensamble_roc_samples_predictions = []


                        tuning_models_dir = f'{cellcnn_path}experiments/experiment_{exp}/outer_fold_{LOPOCV_fold_idx}/ensemble/training/'
                        os.makedirs(tuning_models_dir, exist_ok=True)

                        fold_features = extract_fold_features(train_kfolds, multiple_donations, tot_perc_list) #Fold feature dictionary creation


                        for fold_idx, (train_features, val_features) in fold_features.items():

                            # === Rebuild models per CV fold === #

                            model_trials_dir = f'{tuning_models_dir}/inner_fold_{fold_idx}/models/'
                            all_trials = os.listdir(model_trials_dir)

                            loaded_models_lists = []
                            for i, trial in enumerate(all_trials):
                                model_dir = f'{model_trials_dir}/seed_{i}'
                                with open(os.path.join(model_dir, 'metadata.pkl'), 'rb') as f:
                                    meta = pickle.load(f)

                                model = load_models(CellCnn, meta)
                                loaded_models_lists.append(model)

                            print(f'Iteration {fold_idx}: Models Loaded!')

                            thr_tuning_seed = base_seed + fold_idx*10
                            tuning_prediction_seed_list = generate_seeds(len(all_trials), seed = thr_tuning_seed)

                            # extract Validation patients per CV iteration
                            val_donors_idx = val_features[0] # retrieve patients form fold features dictionary
                            val_datasets_extracted = donation_extraction(val_donors_idx, multiple_donations, ALL_DATASETS)
                            per_donor_original_val_datasets, per_donor_original_val_y = retrieve_labels(val_datasets_extracted, remove = False)

                            # === RES === #
                            val_resample_n = 100000 #same dimension of the AS
                            k = 2 ### 50

                            (_, # predictions divided by patient -> file -> sampled subsets pred
                             total_trial_pred_lists,
                             mean_probs_per_patient) = val_res_pred(loaded_models_lists, per_donor_original_val_datasets, val_resample_n, k, tuning_prediction_seed_list[0])

                            # RES
                            ensemble_mean_probs_per_patient += mean_probs_per_patient # means across weights initializations
                            ensamble_val_y += per_donor_original_val_y

                            # ROC
                            for patient in total_trial_pred_lists:
                                sample_mean_across_subsets_seeds = []
                                for sample in patient:
                                    mean_across_seeds = []
                                    for subset in sample[0]: # assume consistency in the number of subsets
                                        mean_across_seeds.append(np.mean(subset))
                                    sample_mean_across_subsets_seeds.append(np.mean(mean_across_seeds))

                                # store sample mean predictions across seeds and subsets
                                ensamble_roc_samples_predictions += sample_mean_across_subsets_seeds


                        base_seed += len(fold_features)*100

                        # Compute and Save RES
                        tuning_save_dir = f'{cellcnn_path}/experiments/experiment_{exp}/outer_fold_{LOPOCV_fold_idx}/ensemble/tuning/resampling/'
                        os.makedirs(tuning_save_dir, exist_ok=True)

                        ensemble_robust_threshold, tot_per_tr_f1_scores = find_robust_threshold(ensemble_mean_probs_per_patient, 'f1', closest = True)

                        with open(os.path.join(tuning_save_dir, 'ensemble_mean_probs_per_patient.pkl'), 'wb') as f:
                                pickle.dump(ensemble_mean_probs_per_patient, f) # prediction used to tune the threshold

                        with open(os.path.join(tuning_save_dir, 'ensemble_robust_threshold.pkl'), 'wb') as f:
                                pickle.dump(ensemble_robust_threshold, f) # prediction used to tune the threshold

                        with open(os.path.join(tuning_save_dir, 'tot_per_tr_f1_scores.pkl'), 'wb') as f:
                                pickle.dump(tot_per_tr_f1_scores, f) # prediction used to tune the threshold

                        with open(os.path.join(tuning_save_dir, 'total_trial_pred_lists.pkl'), 'wb') as f:
                                pickle.dump(total_trial_pred_lists, f) # prediction used to tune the threshold

                        # Compute and Save ROC
                        tuning_save_dir = f'{cellcnn_path}/experiments/experiment_{exp}/outer_fold_{LOPOCV_fold_idx}/ensemble/tuning/roc/'
                        os.makedirs(tuning_save_dir, exist_ok=True)


                        #### comupute roc curve on resampled to fine the best threshold
                        fpr, tpr, thresholds = metrics.roc_curve(flatten(ensamble_val_y), ensamble_roc_samples_predictions, pos_label=1)# compute ROC curve
                        show_thresholds = (fpr, tpr, thresholds)
                        optimal_idx = np.argmax(tpr >= 0.95)  # index of the threshold that has the highest tpr
                        ensemble_roc_threshold = thresholds[optimal_idx]    # extract the threshold

                        print(f"Best Threshold for MRD (Recall=100%): {ensemble_roc_threshold}")
                        with open(os.path.join(tuning_save_dir, 'ensamble_val_y.pkl'), 'wb') as f:
                                pickle.dump(ensamble_val_y, f) # prediction used to tune the threshold
                        with open(os.path.join(tuning_save_dir, 'ensemble_roc_threshold.pkl'), 'wb') as f:
                                pickle.dump(ensemble_roc_threshold, f) # prediction used to tune the threshold
                        with open(os.path.join(tuning_save_dir, 'ensamble_roc_samples_predictions.pkl'), 'wb') as f:
                                pickle.dump(ensamble_roc_samples_predictions, f) # prediction used to tune the threshold
                        with open(os.path.join(tuning_save_dir, 'show_thresholds.pkl'), 'wb') as f:
                                pickle.dump(show_thresholds, f) # prediction used to tune the threshold


            except Exception as e:
                        print(f'Post-training threshold tuning error!')
                        print(f"Training error: {e}")
                        traceback.print_exc()


            #save seeds outside the ensemble
            tuning_save_dir = f'{cellcnn_path}/experiments/experiment_{exp}/outer_fold_{LOPOCV_fold_idx}/ensemble/'
            os.makedirs(tuning_save_dir, exist_ok=True)


            with open(os.path.join(tuning_save_dir, 'seed_info.pkl'), 'wb') as f:
                                pickle.dump({
                                    'starting_seed': starting_seed,
                                    'LOPOCV_fold_idx': LOPOCV_fold_idx,
                                    'fold_base_seed': fold_base_seed,
                                    'training_split_seed': training_split_seed,
                                    'final_base_seed': base_seed
                                }, f)

            elapsed_time_for_LOPOCV = time.time() - LOPOCV_start
            print(f'elapsed_time_for_LOPOCV fold {LOPOCV_fold_idx}: {elapsed_time_for_LOPOCV}')

            with open(os.path.join(tuning_save_dir, 'elapsed_time_for_LOPOCV.pkl'), 'wb') as f:
                                pickle.dump(elapsed_time_for_LOPOCV, f)

    full_process_time_list.append(elapsed_time_for_LOPOCV)
    if LOPOCV_fold_idx >= end_lopocv_fold:
        break
# Out:
# check seeds: {'starting_seed': 1000, 'LOPOCV_fold_idx': 0, 'fold_base_seed': 1000, 'final_tuning_base_seed': 12510}
# Theta*: (100, 450)
# Model 1. Testing params -> ncells: 100, nsubs: 450
# 5 Fold CV started
#
# CV Fold 0 starts (LOPOCV iteration: 0)
#
# Loading data...
# Labels from Train and Validations Sets have been REMOVED.
# Grid Search Ready!
# Data Loaded...
# Labels from Train and Validations Sets have been REMOVED.
# Grid Search Ready!
# Weight initialization 1 started
# Seed used: 337300
# No labels detected. "labels" variable set to False
# Start generating subsets elabortating samples WITHOUT label column
# Number of training subsets generated: 11
# Number of validation subsets generated: 11
# (5, 0.01, 0.001)
# (5, 0.01, 0.005)
# (5, 1, 0.001)
# (5, 1, 0.005)
# (5, 10, 0.001)
# (5, 10, 0.005)
# (5, 100, 0.001)
# (5, 100, 0.005)
# (7, 0.01, 0.001)
# (7, 0.01, 0.005)
# (7, 1, 0.001)
# (7, 1, 0.005)
# (7, 10, 0.001)
# (7, 10, 0.005)
# (7, 100, 0.001)
# (7, 100, 0.005)
# (9, 0.01, 0.001)
# (9, 0.01, 0.005)
# (9, 1, 0.001)
# (9, 1, 0.005)
# (9, 10, 0.001)
# (9, 10, 0.005)
# (9, 100, 0.001)
# (9, 100, 0.005)
# Total number of selections: 24
#
# # ============================================= #
# Run: 0
#
# Seed: 347300
# Adopted Parameters: (5, 0.01, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 0.01
#
# ==================================================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - f1_score: 0.5025 - loss: 0.6584 - val_f1_score: 0.4000 - val_loss: 0.6562
# Performed epochs: 1
#
# # ============================================= #
# Run: 1
#
# Seed: 347301
# Adopted Parameters: (5, 0.01, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 0.01
#
# ==================================================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - f1_score: 0.4684 - loss: 0.4997 - val_f1_score: 0.4000 - val_loss: 0.7886
# Performed epochs: 1
#
# # ============================================= #
# Run: 2
#
# Seed: 347302
# Adopted Parameters: (5, 1, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 1
#
# ==================================================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.4758 - loss: 0.6283 - val_f1_score: 0.4000 - val_loss: 0.6325
# Performed epochs: 1
#
# # ============================================= #
# Run: 3
#
# Seed: 347303
# Adopted Parameters: (5, 1, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 1
#
# ==================================================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - f1_score: 0.4893 - loss: 0.5320 - val_f1_score: 0.4000 - val_loss: 0.7593
# Performed epochs: 1
#
# # ============================================= #
# Run: 4
#
# Seed: 347304
# Adopted Parameters: (5, 10, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 10
#
# ==================================================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - f1_score: 0.4991 - loss: 0.6715 - val_f1_score: 0.4000 - val_loss: 0.6660
# Performed epochs: 1
#
# # ============================================= #
# Run: 5
#
# Seed: 347305
# Adopted Parameters: (5, 10, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 10
#
# ==================================================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - f1_score: 0.4666 - loss: 0.5039 - val_f1_score: 0.4000 - val_loss: 0.7298
# Performed epochs: 1
#
# # ============================================= #
# Run: 6
#
# Seed: 347306
# Adopted Parameters: (5, 100, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 100
#
# ==================================================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - f1_score: 0.4802 - loss: 0.6755 - val_f1_score: 0.4000 - val_loss: 0.6764
# Performed epochs: 1
#
# # ============================================= #
# Run: 7
#
# Seed: 347307
# Adopted Parameters: (5, 100, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 100
#
# ==================================================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - f1_score: 0.4665 - loss: 0.5509 - val_f1_score: 0.4000 - val_loss: 0.5661
# Performed epochs: 1
#
# # ============================================= #
# Run: 8
#
# Seed: 347308
# Adopted Parameters: (7, 0.01, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 0.01
#
# ==================================================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - f1_score: 0.4948 - loss: 0.6511 - val_f1_score: 0.4000 - val_loss: 0.6454
# Performed epochs: 1
#
# # ============================================= #
# Run: 9
#
# Seed: 347309
# Adopted Parameters: (7, 0.01, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 0.01
#
# ==================================================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - f1_score: 0.4694 - loss: 0.5006 - val_f1_score: 0.4000 - val_loss: 0.7819
# Performed epochs: 1
#
# # ============================================= #
# Run: 10
#
# Seed: 347310
# Adopted Parameters: (7, 1, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 1
#
# ==================================================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - f1_score: 0.4677 - loss: 0.6428 - val_f1_score: 0.4000 - val_loss: 0.6471
# Performed epochs: 1
#
# # ============================================= #
# Run: 11
#
# Seed: 347311
# Adopted Parameters: (7, 1, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 1
#
# ==================================================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - f1_score: 0.4703 - loss: 0.4960 - val_f1_score: 0.4000 - val_loss: 0.9208
# Performed epochs: 1
#
# # ============================================= #
# Run: 12
#
# Seed: 347312
# Adopted Parameters: (7, 10, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 10
#
# ==================================================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - f1_score: 0.4785 - loss: 0.6600 - val_f1_score: 0.4000 - val_loss: 0.6497
# Performed epochs: 1
#
# # ============================================= #
# Run: 13
#
# Seed: 347313
# Adopted Parameters: (7, 10, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 10
#
# ==================================================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - f1_score: 0.4694 - loss: 0.5259 - val_f1_score: 0.4000 - val_loss: 0.7856
# Performed epochs: 1
#
# # ============================================= #
# Run: 14
#
# Seed: 347314
# Adopted Parameters: (7, 100, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 100
#
# ==================================================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - f1_score: 0.4676 - loss: 0.6704 - val_f1_score: 0.4000 - val_loss: 0.6653
# Performed epochs: 1
#
# # ============================================= #
# Run: 15
#
# Seed: 347315
# Adopted Parameters: (7, 100, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 100
#
# ==================================================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - f1_score: 0.4827 - loss: 0.5807 - val_f1_score: 0.4000 - val_loss: 0.6256
# Performed epochs: 1
#
# # ============================================= #
# Run: 16
#
# Seed: 347316
# Adopted Parameters: (9, 0.01, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 9
#
#
#  k% max pooling: 0.01
#
# ==================================================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - f1_score: 0.5018 - loss: 0.6356 - val_f1_score: 0.4000 - val_loss: 0.6278
# Performed epochs: 1
#
# # ============================================= #
# Run: 17
#
# Seed: 347317
# Adopted Parameters: (9, 0.01, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 9
#
#
#  k% max pooling: 0.01
#
# ==================================================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.4643 - loss: 0.4580 - val_f1_score: 0.4000 - val_loss: 0.7935
# Performed epochs: 1
#
# # ============================================= #
# Run: 18
#
# Seed: 347318
# Adopted Parameters: (9, 1, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 9
#
#
#  k% max pooling: 1
#
# ==================================================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - f1_score: 0.4644 - loss: 0.6332 - val_f1_score: 0.4000 - val_loss: 0.6431
# Performed epochs: 1
#
# # ============================================= #
# Run: 19
#
# Seed: 347319
# Adopted Parameters: (9, 1, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 9
#
#
#  k% max pooling: 1
#
# ==================================================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - f1_score: 0.4689 - loss: 0.4657 - val_f1_score: 0.4000 - val_loss: 0.7962
# Performed epochs: 1
#
# # ============================================= #
# Run: 20
#
# Seed: 347320
# Adopted Parameters: (9, 10, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 9
#
#
#  k% max pooling: 10
#
# ==================================================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - f1_score: 0.4807 - loss: 0.6347 - val_f1_score: 0.4000 - val_loss: 0.6185
# Performed epochs: 1
#
# # ============================================= #
# Run: 21
#
# Seed: 347321
# Adopted Parameters: (9, 10, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 9
#
#
#  k% max pooling: 10
#
# ==================================================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - f1_score: 0.4824 - loss: 0.4844 - val_f1_score: 0.4000 - val_loss: 0.8379
# Performed epochs: 1
#
# # ============================================= #
# Run: 22
#
# Seed: 347322
# Adopted Parameters: (9, 100, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 9
#
#
#  k% max pooling: 100
#
# ==================================================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - f1_score: 0.4709 - loss: 0.6648 - val_f1_score: 0.4000 - val_loss: 0.6631
# Performed epochs: 1
#
# # ============================================= #
# Run: 23
#
# Seed: 347323
# Adopted Parameters: (9, 100, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 9
#
#
#  k% max pooling: 100
#
# ==================================================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - f1_score: 0.4715 - loss: 0.5263 - val_f1_score: 0.4000 - val_loss: 0.6598
# Performed epochs: 1
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# Ground thruth labels: [1, 0]
# Weight Initialization 1 out of 1 started!
# seed: 747712. Type: <class 'numpy.int64'>
# seed: 747712. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 925ms/step
# Done
# Trial 1 Done!
#
# Save CellCNN Prediction results
# Start Resampling prediction using ROC threshold
# Ground thruth labels per patient: [[1, 0]]
# 2
# Weight Initialization 1 out of 1 started!
# seed: 102429. Type: <class 'numpy.int64'>
# seed: 102429. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# ==================================================
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7ac81d9a34c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7ac81d9e6ac0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Done
# Trial 1 Done!
#
# 2
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# Weight Initialization 1 out of 1 started!
# seed: 269810. Type: <class 'numpy.int64'>
# seed: 269810. Type: <class 'int'>
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# Done
# Trial 1 Done!
#
#
# End CV Fold 0. Time Elapsed: -770.7136142253876
# Time elapsed from start LOPOCV iteration: -772.0493876934052
#
#
# CV Fold 1 starts (LOPOCV iteration: 0)
#
# Loading data...
# Labels from Train and Validations Sets have been REMOVED.
# Grid Search Ready!
# Data Loaded...
# Labels from Train and Validations Sets have been REMOVED.
# Grid Search Ready!
# Weight initialization 1 started
# Seed used: 194956
# No labels detected. "labels" variable set to False
# Start generating subsets elabortating samples WITHOUT label column
# Number of training subsets generated: 11
# Number of validation subsets generated: 11
# (5, 0.01, 0.001)
# (5, 0.01, 0.005)
# (5, 1, 0.001)
# (5, 1, 0.005)
# (5, 10, 0.001)
# (5, 10, 0.005)
# (5, 100, 0.001)
# (5, 100, 0.005)
# (7, 0.01, 0.001)
# (7, 0.01, 0.005)
# (7, 1, 0.001)
# (7, 1, 0.005)
# (7, 10, 0.001)
# (7, 10, 0.005)
# (7, 100, 0.001)
# (7, 100, 0.005)
# (9, 0.01, 0.001)
# (9, 0.01, 0.005)
# (9, 1, 0.001)
# (9, 1, 0.005)
# (9, 10, 0.001)
# (9, 10, 0.005)
# (9, 100, 0.001)
# (9, 100, 0.005)
# Total number of selections: 24
#
# # ============================================= #
# Run: 0
#
# Seed: 204956
# Adopted Parameters: (5, 0.01, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 0.01
#
# ==================================================
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - f1_score: 0.4868 - loss: 0.6598 - val_f1_score: 0.5000 - val_loss: 0.5444
# Performed epochs: 1
#
# # ============================================= #
# Run: 1
#
# Seed: 204957
# Adopted Parameters: (5, 0.01, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 0.01
#
# ==================================================
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - f1_score: 0.4630 - loss: 0.5461 - val_f1_score: 0.5000 - val_loss: 0.1293
# Performed epochs: 1
#
# # ============================================= #
# Run: 2
#
# Seed: 204958
# Adopted Parameters: (5, 1, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 1
#
# ==================================================
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - f1_score: 0.4946 - loss: 0.6652 - val_f1_score: 0.5000 - val_loss: 0.5499
# Performed epochs: 1
#
# # ============================================= #
# Run: 3
#
# Seed: 204959
# Adopted Parameters: (5, 1, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 1
#
# ==================================================
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - f1_score: 0.4430 - loss: 0.5448 - val_f1_score: 0.5000 - val_loss: 0.1793
# Performed epochs: 1
#
# # ============================================= #
# Run: 4
#
# Seed: 204960
# Adopted Parameters: (5, 10, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 10
#
# ==================================================
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - f1_score: 0.5192 - loss: 0.6627 - val_f1_score: 0.5000 - val_loss: 0.5774
# Performed epochs: 1
#
# # ============================================= #
# Run: 5
#
# Seed: 204961
# Adopted Parameters: (5, 10, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 10
#
# ==================================================
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - f1_score: 0.4549 - loss: 0.5445 - val_f1_score: 0.5000 - val_loss: 0.1631
# Performed epochs: 1
#
# # ============================================= #
# Run: 6
#
# Seed: 204962
# Adopted Parameters: (5, 100, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 100
#
# ==================================================
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - f1_score: 0.4517 - loss: 0.6698 - val_f1_score: 0.5000 - val_loss: 0.6153
# Performed epochs: 1
#
# # ============================================= #
# Run: 7
#
# Seed: 204963
# Adopted Parameters: (5, 100, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 100
#
# ==================================================
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - f1_score: 0.4463 - loss: 0.5783 - val_f1_score: 0.5000 - val_loss: 0.2646
# Performed epochs: 1
#
# # ============================================= #
# Run: 8
#
# Seed: 204964
# Adopted Parameters: (7, 0.01, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 0.01
#
# ==================================================
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - f1_score: 0.5090 - loss: 0.6738 - val_f1_score: 0.5000 - val_loss: 0.5821
# Performed epochs: 1
#
# # ============================================= #
# Run: 9
#
# Seed: 204965
# Adopted Parameters: (7, 0.01, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 0.01
#
# ==================================================
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - f1_score: 0.4504 - loss: 0.5345 - val_f1_score: 0.5000 - val_loss: 0.1495
# Performed epochs: 1
#
# # ============================================= #
# Run: 10
#
# Seed: 204966
# Adopted Parameters: (7, 1, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 1
#
# ==================================================
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - f1_score: 0.4924 - loss: 0.6544 - val_f1_score: 0.5000 - val_loss: 0.5316
# Performed epochs: 1
#
# # ============================================= #
# Run: 11
#
# Seed: 204967
# Adopted Parameters: (7, 1, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 1
#
# ==================================================
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - f1_score: 0.4475 - loss: 0.5382 - val_f1_score: 0.5000 - val_loss: 0.1551
# Performed epochs: 1
#
# # ============================================= #
# Run: 12
#
# Seed: 204968
# Adopted Parameters: (7, 10, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 10
#
# ==================================================
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.4569 - loss: 0.6537 - val_f1_score: 0.5000 - val_loss: 0.5384
# Performed epochs: 1
#
# # ============================================= #
# Run: 13
#
# Seed: 204969
# Adopted Parameters: (7, 10, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 10
#
# ==================================================
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - f1_score: 0.4507 - loss: 0.4903 - val_f1_score: 0.5000 - val_loss: 0.1312
# Performed epochs: 1
#
# # ============================================= #
# Run: 14
#
# Seed: 204970
# Adopted Parameters: (7, 100, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 100
#
# ==================================================
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - f1_score: 0.4416 - loss: 0.6664 - val_f1_score: 0.5000 - val_loss: 0.5966
# Performed epochs: 1
#
# # ============================================= #
# Run: 15
#
# Seed: 204971
# Adopted Parameters: (7, 100, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 100
#
# ==================================================
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - f1_score: 0.4487 - loss: 0.5583 - val_f1_score: 0.5000 - val_loss: 0.2004
# Performed epochs: 1
#
# # ============================================= #
# Run: 16
#
# Seed: 204972
# Adopted Parameters: (9, 0.01, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 9
#
#
#  k% max pooling: 0.01
#
# ==================================================
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - f1_score: 0.4508 - loss: 0.6353 - val_f1_score: 0.5000 - val_loss: 0.4157
# Performed epochs: 1
#
# # ============================================= #
# Run: 17
#
# Seed: 204973
# Adopted Parameters: (9, 0.01, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 9
#
#
#  k% max pooling: 0.01
#
# ==================================================
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - f1_score: 0.4511 - loss: 0.5147 - val_f1_score: 0.5000 - val_loss: 0.1220
# Performed epochs: 1
#
# # ============================================= #
# Run: 18
#
# Seed: 204974
# Adopted Parameters: (9, 1, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 9
#
#
#  k% max pooling: 1
#
# ==================================================
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - f1_score: 0.5135 - loss: 0.6752 - val_f1_score: 0.5000 - val_loss: 0.5948
# Performed epochs: 1
#
# # ============================================= #
# Run: 19
#
# Seed: 204975
# Adopted Parameters: (9, 1, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 9
#
#
#  k% max pooling: 1
#
# ==================================================
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - f1_score: 0.4426 - loss: 0.5193 - val_f1_score: 0.5000 - val_loss: 0.1495
# Performed epochs: 1
#
# # ============================================= #
# Run: 20
#
# Seed: 204976
# Adopted Parameters: (9, 10, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 9
#
#
#  k% max pooling: 10
#
# ==================================================
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - f1_score: 0.4782 - loss: 0.6422 - val_f1_score: 0.5000 - val_loss: 0.4777
# Performed epochs: 1
#
# # ============================================= #
# Run: 21
#
# Seed: 204977
# Adopted Parameters: (9, 10, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 9
#
#
#  k% max pooling: 10
#
# ==================================================
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - f1_score: 0.4674 - loss: 0.5177 - val_f1_score: 0.5000 - val_loss: 0.1364
# Performed epochs: 1
#
# # ============================================= #
# Run: 22
#
# Seed: 204978
# Adopted Parameters: (9, 100, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 9
#
#
#  k% max pooling: 100
#
# ==================================================
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - f1_score: 0.4681 - loss: 0.6635 - val_f1_score: 0.5000 - val_loss: 0.5935
# Performed epochs: 1
#
# # ============================================= #
# Run: 23
#
# Seed: 204979
# Adopted Parameters: (9, 100, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 9
#
#
#  k% max pooling: 100
#
# ==================================================
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - f1_score: 0.4496 - loss: 0.5390 - val_f1_score: 0.5000 - val_loss: 0.1559
# Performed epochs: 1
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:3596: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.12/dist-packages/numpy/_core/_methods.py:138: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Ground thruth labels: [1, 0]
# Weight Initialization 1 out of 1 started!
# seed: 916938. Type: <class 'numpy.int64'>
# seed: 916938. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 839ms/step
# Done
# Trial 1 Done!
#
# Save CellCNN Prediction results
# Start Resampling prediction using ROC threshold
# Ground thruth labels per patient: [[1, 0]]
# 2
# Weight Initialization 1 out of 1 started!
# seed: 113150. Type: <class 'numpy.int64'>
# seed: 113150. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# Done
# Trial 1 Done!
#
# 2
# Weight Initialization 1 out of 1 started!
# seed: 601288. Type: <class 'numpy.int64'>
# seed: 601288. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Done
# Trial 1 Done!
#
#
# End CV Fold 1. Time Elapsed: -753.5942492485046
# Time elapsed from start LOPOCV iteration: -1525.6437571048737
#
#
# CV Fold 2 starts (LOPOCV iteration: 0)
#
# Loading data...
# Labels from Train and Validations Sets have been REMOVED.
# Grid Search Ready!
# Data Loaded...
# Labels from Train and Validations Sets have been REMOVED.
# Grid Search Ready!
# Weight initialization 1 started
# Seed used: 373505
# No labels detected. "labels" variable set to False
# Start generating subsets elabortating samples WITHOUT label column
# Number of training subsets generated: 11
# Number of validation subsets generated: 11
# (5, 0.01, 0.001)
# (5, 0.01, 0.005)
# (5, 1, 0.001)
# (5, 1, 0.005)
# (5, 10, 0.001)
# (5, 10, 0.005)
# (5, 100, 0.001)
# (5, 100, 0.005)
# (7, 0.01, 0.001)
# (7, 0.01, 0.005)
# (7, 1, 0.001)
# (7, 1, 0.005)
# (7, 10, 0.001)
# (7, 10, 0.005)
# (7, 100, 0.001)
# (7, 100, 0.005)
# (9, 0.01, 0.001)
# (9, 0.01, 0.005)
# (9, 1, 0.001)
# (9, 1, 0.005)
# (9, 10, 0.001)
# (9, 10, 0.005)
# (9, 100, 0.001)
# (9, 100, 0.005)
# Total number of selections: 24
#
# # ============================================= #
# Run: 0
#
# Seed: 383505
# Adopted Parameters: (5, 0.01, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 0.01
#
# ==================================================
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - f1_score: 0.4818 - loss: 0.6511 - val_f1_score: 0.4444 - val_loss: 0.6067
# Performed epochs: 1
#
# # ============================================= #
# Run: 1
#
# Seed: 383506
# Adopted Parameters: (5, 0.01, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 0.01
#
# ==================================================
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - f1_score: 0.4707 - loss: 0.5601 - val_f1_score: 0.4444 - val_loss: 0.5314
# Performed epochs: 1
#
# # ============================================= #
# Run: 2
#
# Seed: 383507
# Adopted Parameters: (5, 1, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 1
#
# ==================================================
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - f1_score: 0.4712 - loss: 0.6496 - val_f1_score: 0.4444 - val_loss: 0.6129
# Performed epochs: 1
#
# # ============================================= #
# Run: 3
#
# Seed: 383508
# Adopted Parameters: (5, 1, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 1
#
# ==================================================
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - f1_score: 0.4711 - loss: 0.5888 - val_f1_score: 0.4444 - val_loss: 0.5438
# Performed epochs: 1
#
# # ============================================= #
# Run: 4
#
# Seed: 383509
# Adopted Parameters: (5, 10, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 10
#
# ==================================================
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - f1_score: 0.4793 - loss: 0.6532 - val_f1_score: 0.4444 - val_loss: 0.6177
# Performed epochs: 1
#
# # ============================================= #
# Run: 5
#
# Seed: 383510
# Adopted Parameters: (5, 10, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 10
#
# ==================================================
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - f1_score: 0.4851 - loss: 0.5570 - val_f1_score: 0.4444 - val_loss: 0.4418
# Performed epochs: 1
#
# # ============================================= #
# Run: 6
#
# Seed: 383511
# Adopted Parameters: (5, 100, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 100
#
# ==================================================
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - f1_score: 0.4660 - loss: 0.6776 - val_f1_score: 0.4444 - val_loss: 0.6577
# Performed epochs: 1
#
# # ============================================= #
# Run: 7
#
# Seed: 383512
# Adopted Parameters: (5, 100, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 100
#
# ==================================================
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - f1_score: 0.4544 - loss: 0.5692 - val_f1_score: 0.4444 - val_loss: 0.4485
# Performed epochs: 1
#
# # ============================================= #
# Run: 8
#
# Seed: 383513
# Adopted Parameters: (7, 0.01, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 0.01
#
# ==================================================
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - f1_score: 0.4488 - loss: 0.6174 - val_f1_score: 0.4444 - val_loss: 0.5654
# Performed epochs: 1
#
# # ============================================= #
# Run: 9
#
# Seed: 383514
# Adopted Parameters: (7, 0.01, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 0.01
#
# ==================================================
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - f1_score: 0.4623 - loss: 0.5195 - val_f1_score: 0.4444 - val_loss: 0.4834
# Performed epochs: 1
#
# # ============================================= #
# Run: 10
#
# Seed: 383515
# Adopted Parameters: (7, 1, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 1
#
# ==================================================
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - f1_score: 0.4633 - loss: 0.6350 - val_f1_score: 0.4444 - val_loss: 0.5868
# Performed epochs: 1
#
# # ============================================= #
# Run: 11
#
# Seed: 383516
# Adopted Parameters: (7, 1, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 1
#
# ==================================================
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - f1_score: 0.4534 - loss: 0.5079 - val_f1_score: 0.4444 - val_loss: 0.4404
# Performed epochs: 1
#
# # ============================================= #
# Run: 12
#
# Seed: 383517
# Adopted Parameters: (7, 10, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 10
#
# ==================================================
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - f1_score: 0.4695 - loss: 0.6538 - val_f1_score: 0.4444 - val_loss: 0.6093
# Performed epochs: 1
#
# # ============================================= #
# Run: 13
#
# Seed: 383518
# Adopted Parameters: (7, 10, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 10
#
# ==================================================
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - f1_score: 0.4540 - loss: 0.5243 - val_f1_score: 0.4444 - val_loss: 0.4310
# Performed epochs: 1
#
# # ============================================= #
# Run: 14
#
# Seed: 383519
# Adopted Parameters: (7, 100, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 100
#
# ==================================================
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - f1_score: 0.4694 - loss: 0.6770 - val_f1_score: 0.4444 - val_loss: 0.6598
# Performed epochs: 1
#
# # ============================================= #
# Run: 15
#
# Seed: 383520
# Adopted Parameters: (7, 100, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 100
#
# ==================================================
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - f1_score: 0.4516 - loss: 0.5643 - val_f1_score: 0.4444 - val_loss: 0.4483
# Performed epochs: 1
#
# # ============================================= #
# Run: 16
#
# Seed: 383521
# Adopted Parameters: (9, 0.01, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 9
#
#
#  k% max pooling: 0.01
#
# ==================================================
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - f1_score: 0.4693 - loss: 0.6367 - val_f1_score: 0.4444 - val_loss: 0.5856
# Performed epochs: 1
#
# # ============================================= #
# Run: 17
#
# Seed: 383522
# Adopted Parameters: (9, 0.01, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 9
#
#
#  k% max pooling: 0.01
#
# ==================================================
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - f1_score: 0.4558 - loss: 0.5158 - val_f1_score: 0.4444 - val_loss: 0.4689
# Performed epochs: 1
#
# # ============================================= #
# Run: 18
#
# Seed: 383523
# Adopted Parameters: (9, 1, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 9
#
#
#  k% max pooling: 1
#
# ==================================================
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - f1_score: 0.4593 - loss: 0.6534 - val_f1_score: 0.4444 - val_loss: 0.6011
# Performed epochs: 1
#
# # ============================================= #
# Run: 19
#
# Seed: 383524
# Adopted Parameters: (9, 1, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 9
#
#
#  k% max pooling: 1
#
# ==================================================
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - f1_score: 0.4560 - loss: 0.4832 - val_f1_score: 0.4444 - val_loss: 0.4244
# Performed epochs: 1
#
# # ============================================= #
# Run: 20
#
# Seed: 383525
# Adopted Parameters: (9, 10, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 9
#
#
#  k% max pooling: 10
#
# ==================================================
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - f1_score: 0.5102 - loss: 0.6594 - val_f1_score: 0.4444 - val_loss: 0.6247
# Performed epochs: 1
#
# # ============================================= #
# Run: 21
#
# Seed: 383526
# Adopted Parameters: (9, 10, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 9
#
#
#  k% max pooling: 10
#
# ==================================================
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - f1_score: 0.4540 - loss: 0.5076 - val_f1_score: 0.4444 - val_loss: 0.4262
# Performed epochs: 1
#
# # ============================================= #
# Run: 22
#
# Seed: 383527
# Adopted Parameters: (9, 100, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 9
#
#
#  k% max pooling: 100
#
# ==================================================
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - f1_score: 0.4542 - loss: 0.6734 - val_f1_score: 0.4444 - val_loss: 0.6487
# Performed epochs: 1
#
# # ============================================= #
# Run: 23
#
# Seed: 383528
# Adopted Parameters: (9, 100, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 9
#
#
#  k% max pooling: 100
#
# ==================================================
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - f1_score: 0.4511 - loss: 0.5416 - val_f1_score: 0.4444 - val_loss: 0.4330
# Performed epochs: 1
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# Ground thruth labels: [1, 0]
# Weight Initialization 1 out of 1 started!
# seed: 669710. Type: <class 'numpy.int64'>
# seed: 669710. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 841ms/step
# Done
# Trial 1 Done!
#
# Save CellCNN Prediction results
# Start Resampling prediction using ROC threshold
# Ground thruth labels per patient: [[1, 0]]
# 2
# Weight Initialization 1 out of 1 started!
# seed: 727331. Type: <class 'numpy.int64'>
# seed: 727331. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Done
# Trial 1 Done!
#
# 2
# Weight Initialization 1 out of 1 started!
# seed: 546374. Type: <class 'numpy.int64'>
# seed: 546374. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# Done
# Trial 1 Done!
#
#
# End CV Fold 2. Time Elapsed: -767.0059814453125
# Time elapsed from start LOPOCV iteration: -2292.649838924408
#
#
# CV Fold 3 starts (LOPOCV iteration: 0)
#
# Loading data...
# Labels from Train and Validations Sets have been REMOVED.
# Grid Search Ready!
# Data Loaded...
# Labels from Train and Validations Sets have been REMOVED.
# Grid Search Ready!
# Weight initialization 1 started
# Seed used: 47696
# No labels detected. "labels" variable set to False
# Start generating subsets elabortating samples WITHOUT label column
# Number of training subsets generated: 11
# Number of validation subsets generated: 11
# (5, 0.01, 0.001)
# (5, 0.01, 0.005)
# (5, 1, 0.001)
# (5, 1, 0.005)
# (5, 10, 0.001)
# (5, 10, 0.005)
# (5, 100, 0.001)
# (5, 100, 0.005)
# (7, 0.01, 0.001)
# (7, 0.01, 0.005)
# (7, 1, 0.001)
# (7, 1, 0.005)
# (7, 10, 0.001)
# (7, 10, 0.005)
# (7, 100, 0.001)
# (7, 100, 0.005)
# (9, 0.01, 0.001)
# (9, 0.01, 0.005)
# (9, 1, 0.001)
# (9, 1, 0.005)
# (9, 10, 0.001)
# (9, 10, 0.005)
# (9, 100, 0.001)
# (9, 100, 0.005)
# Total number of selections: 24
#
# # ============================================= #
# Run: 0
#
# Seed: 57696
# Adopted Parameters: (5, 0.01, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 0.01
#
# ==================================================
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - f1_score: 0.4559 - loss: 0.6425 - val_f1_score: 0.4286 - val_loss: 0.6131
# Performed epochs: 1
#
# # ============================================= #
# Run: 1
#
# Seed: 57697
# Adopted Parameters: (5, 0.01, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 0.01
#
# ==================================================
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - f1_score: 0.4757 - loss: 0.5168 - val_f1_score: 0.4286 - val_loss: 0.5336
# Performed epochs: 1
#
# # ============================================= #
# Run: 2
#
# Seed: 57698
# Adopted Parameters: (5, 1, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 1
#
# ==================================================
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - f1_score: 0.4801 - loss: 0.6690 - val_f1_score: 0.4286 - val_loss: 0.6449
# Performed epochs: 1
#
# # ============================================= #
# Run: 3
#
# Seed: 57699
# Adopted Parameters: (5, 1, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 1
#
# ==================================================
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - f1_score: 0.4655 - loss: 0.5511 - val_f1_score: 0.4286 - val_loss: 0.5677
# Performed epochs: 1
#
# # ============================================= #
# Run: 4
#
# Seed: 57700
# Adopted Parameters: (5, 10, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 10
#
# ==================================================
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - f1_score: 0.4544 - loss: 0.6551 - val_f1_score: 0.4286 - val_loss: 0.6300
# Performed epochs: 1
#
# # ============================================= #
# Run: 5
#
# Seed: 57701
# Adopted Parameters: (5, 10, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 10
#
# ==================================================
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - f1_score: 0.4569 - loss: 0.5067 - val_f1_score: 0.4286 - val_loss: 0.5238
# Performed epochs: 1
#
# # ============================================= #
# Run: 6
#
# Seed: 57702
# Adopted Parameters: (5, 100, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 100
#
# ==================================================
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - f1_score: 0.4752 - loss: 0.6720 - val_f1_score: 0.4286 - val_loss: 0.6577
# Performed epochs: 1
#
# # ============================================= #
# Run: 7
#
# Seed: 57703
# Adopted Parameters: (5, 100, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 5
#
#
#  k% max pooling: 100
#
# ==================================================
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - f1_score: 0.4596 - loss: 0.5561 - val_f1_score: 0.4286 - val_loss: 0.4894
# Performed epochs: 1
#
# # ============================================= #
# Run: 8
#
# Seed: 57704
# Adopted Parameters: (7, 0.01, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 0.01
#
# ==================================================
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - f1_score: 0.4554 - loss: 0.6258 - val_f1_score: 0.4286 - val_loss: 0.5854
# Performed epochs: 1
#
# # ============================================= #
# Run: 9
#
# Seed: 57705
# Adopted Parameters: (7, 0.01, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 0.01
#
# ==================================================
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - f1_score: 0.4780 - loss: 0.5024 - val_f1_score: 0.4286 - val_loss: 0.5049
# Performed epochs: 1
#
# # ============================================= #
# Run: 10
#
# Seed: 57706
# Adopted Parameters: (7, 1, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 1
#
# ==================================================
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - f1_score: 0.4570 - loss: 0.6317 - val_f1_score: 0.4286 - val_loss: 0.5979
# Performed epochs: 1
#
# # ============================================= #
# Run: 11
#
# Seed: 57707
# Adopted Parameters: (7, 1, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 1
#
# ==================================================
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - f1_score: 0.4566 - loss: 0.5056 - val_f1_score: 0.4286 - val_loss: 0.5078
# Performed epochs: 1
#
# # ============================================= #
# Run: 12
#
# Seed: 57708
# Adopted Parameters: (7, 10, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 10
#
# ==================================================
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - f1_score: 0.4595 - loss: 0.6336 - val_f1_score: 0.4286 - val_loss: 0.5981
# Performed epochs: 1
#
# # ============================================= #
# Run: 13
#
# Seed: 57709
# Adopted Parameters: (7, 10, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 10
#
# ==================================================
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - f1_score: 0.4642 - loss: 0.5155 - val_f1_score: 0.4286 - val_loss: 0.5117
# Performed epochs: 1
#
# # ============================================= #
# Run: 14
#
# Seed: 57710
# Adopted Parameters: (7, 100, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 100
#
# ==================================================
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - f1_score: 0.4523 - loss: 0.6645 - val_f1_score: 0.4286 - val_loss: 0.6429
# Performed epochs: 1
#
# # ============================================= #
# Run: 15
#
# Seed: 57711
# Adopted Parameters: (7, 100, 0.005)
#
#  Learning Rate: 0.005
#
#
#  Number of filters: 7
#
#
#  k% max pooling: 100
#
# ==================================================
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - f1_score: 0.4587 - loss: 0.5424 - val_f1_score: 0.4286 - val_loss: 0.5210
# Performed epochs: 1
#
# # ============================================= #
# Run: 16
#
# Seed: 57712
# Adopted Parameters: (9, 0.01, 0.001)
#
#  Learning Rate: 0.001
#
#
#  Number of filters: 9
#
#
#  k% max pooling: 0.01
#
# ==================================================
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - f1_score: 0.4596 - loss: 0.6296 - val_f1_score: 0.4286 - val_loss: 0.5960
# Performed epochs: 1
#
# ...
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# Done
# Trial 1 Done!
#
# Weight Initialization 1 out of 1 started!
# seed: 646234. Type: <class 'numpy.int64'>
# seed: 646234. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# Done
# Trial 1 Done!
#
# Weight Initialization 1 out of 1 started!
# seed: 383297. Type: <class 'numpy.int64'>
# seed: 383297. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Done
# Trial 1 Done!
#
# Weight Initialization 1 out of 1 started!
# seed: 945553. Type: <class 'numpy.int64'>
# seed: 945553. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Done
# Trial 1 Done!
#
# Weight Initialization 1 out of 1 started!
# seed: 464717. Type: <class 'numpy.int64'>
# seed: 464717. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Done
# Trial 1 Done!
#
# Weight Initialization 1 out of 1 started!
# seed: 159347. Type: <class 'numpy.int64'>
# seed: 159347. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# Done
# Trial 1 Done!
#
# Iteration 1: Models Loaded!
# Weight Initialization 1 out of 1 started!
# seed: 110108. Type: <class 'numpy.int64'>
# seed: 110108. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# Done
# Trial 1 Done!
#
# Weight Initialization 1 out of 1 started!
# seed: 339693. Type: <class 'numpy.int64'>
# seed: 339693. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# Done
# Trial 1 Done!
#
# Iteration 2: Models Loaded!
# Weight Initialization 1 out of 1 started!
# seed: 618311. Type: <class 'numpy.int64'>
# seed: 618311. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# Done
# Trial 1 Done!
#
# Weight Initialization 1 out of 1 started!
# seed: 240323. Type: <class 'numpy.int64'>
# seed: 240323. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# Done
# Trial 1 Done!
#
# Weight Initialization 1 out of 1 started!
# seed: 504550. Type: <class 'numpy.int64'>
# seed: 504550. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# Done
# Trial 1 Done!
#
# Weight Initialization 1 out of 1 started!
# seed: 140791. Type: <class 'numpy.int64'>
# seed: 140791. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# Done
# Trial 1 Done!
#
# Weight Initialization 1 out of 1 started!
# seed: 579180. Type: <class 'numpy.int64'>
# seed: 579180. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# Done
# Trial 1 Done!
#
# Iteration 3: Models Loaded!
# Weight Initialization 1 out of 1 started!
# seed: 123488. Type: <class 'numpy.int64'>
# seed: 123488. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# Done
# Trial 1 Done!
#
# Weight Initialization 1 out of 1 started!
# seed: 977226. Type: <class 'numpy.int64'>
# seed: 977226. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# Done
# Trial 1 Done!
#
# Weight Initialization 1 out of 1 started!
# seed: 690983. Type: <class 'numpy.int64'>
# seed: 690983. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Done
# Trial 1 Done!
#
# Weight Initialization 1 out of 1 started!
# seed: 501908. Type: <class 'numpy.int64'>
# seed: 501908. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Done
# Trial 1 Done!
#
# Iteration 4: Models Loaded!
# Weight Initialization 1 out of 1 started!
# seed: 209106. Type: <class 'numpy.int64'>
# seed: 209106. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# Done
# Trial 1 Done!
#
# Weight Initialization 1 out of 1 started!
# seed: 305740. Type: <class 'numpy.int64'>
# seed: 305740. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# Done
# Trial 1 Done!
#
# Weight Initialization 1 out of 1 started!
# seed: 342264. Type: <class 'numpy.int64'>
# seed: 342264. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# Done
# Trial 1 Done!
#
# Weight Initialization 1 out of 1 started!
# seed: 380104. Type: <class 'numpy.int64'>
# seed: 380104. Type: <class 'int'>
# ==================================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# ==================================================
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Done
# Trial 1 Done!
#
# Chosen threshold: 50. Associated F1_score: 0.8947
# Best Threshold for MRD (Recall=100%): 0.6918728748957317
# elapsed_time_for_LOPOCV fold 0: 3975.0384199619293
# CPU times: user 1h 4min 15s, sys: 57.7 s, total: 1h 5min 13s
# Wall time: 1h 6min 15s
